# %%
import pandas as pd
from scipy import stats
import numpy as npy
import seaborn as sb
import matplotlib as mpl
data = pd.read_csv("data.csv",delimiter=";")
cm = sb.light_palette("gold", as_cmap=True)
data.style.background_gradient(cmap=cm)

colum = data.columns.tolist()
for x in colum :
    ds = [x for x in data[x]]
    desc = data[x].describe()
    array = [x for x in desc]
    print("Detail kolom",x)
    print("rata-rata: ",array[1])
    print("Median: ",npy.median(npy.array(ds)))
    print("Modus: ",stats.mode(ds))
    print("Standard deviasi: ",npy.std(ds))
    print("varian: ",stats.variation(ds))
    print("Skewness: ",stats.skew(ds))
    print("Quartil 1: ",array[4])
    print("Quartil 2: ",array[5])
    print("Quartil 3: ",array[6])
    sb.distplot(data[x])
    
    print("\n")
# Out:
# Detail kolom A
# rata-rata:  170.174
# Median:  171.0
# Modus:  ModeResult(mode=array([173]), count=array([18]))
# Standard deviasi:  12.032112200274728
# varian:  0.07070476218620193
# Skewness:  -0.04060033131009136
# Quartil 1:  160.0
# Quartil 2:  171.0
# Quartil 3:  180.0
#
#
# Detail kolom B
# rata-rata:  169.312
# Median:  169.0
# Modus:  ModeResult(mode=array([153]), count=array([19]))
# Standard deviasi:  11.684462161349147
# varian:  0.06901142365189204
# Skewness:  0.06861452896692723
# Quartil 1:  160.0
# Quartil 2:  169.0
# Quartil 3:  179.25
#
#
# Detail kolom C
# rata-rata:  169.572
# Median:  169.0
# Modus:  ModeResult(mode=array([161]), count=array([20]))
# Standard deviasi:  11.465287436431762
# varian:  0.06761309317830633
# Skewness:  0.07953572655498663
# Quartil 1:  160.0
# Quartil 2:  169.0
# Quartil 3:  178.0
#
#
# Detail kolom D
# rata-rata:  169.104
# Median:  168.0
# Modus:  ModeResult(mode=array([153]), count=array([19]))
# Standard deviasi:  11.842515948902074
# varian:  0.07003096289207868
# Skewness:  0.11855958498956976
# Quartil 1:  159.0
# Quartil 2:  168.0
# Quartil 3:  180.0
